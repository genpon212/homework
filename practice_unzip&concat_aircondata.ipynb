# %% [markdown]
# # practice of parallel processing

# %%
import sys
sys.version
# Out:
# '3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]'

# %%
pip install joblib

# %%
from joblib import parallel, delayed

#並列処理の記述
#結果 = Parallel(n_jobs=-1)(delayed(処理名)(変数)繰り返し構文など)
#n_jobsに-1を指定すると、そのコンピュータのコア数に合わせて処理を分割、1を指定すると逐次処理と同じになる。

# %%
#逐次処理とJoblibを使用した並列処理の処理速度比較
from time import time

def proc(n):
    return sum([m * n for m in range(10000)])

# 処理時間計測開始
start = time()

# 時間がかかる処理
total = 0
for i in range(10000):
    total += proc(i)
    
# 処理結果を表示
print(total)
print('逐次処理', (time()-start), "秒")
# Out:
# 2499500025000000
# 逐次処理 11.572292804718018 秒

# %%
from joblib import Parallel, delayed
from time import time

def proc(n):
    return sum([m * n for m in range(10000)])

start = time()

sub = Parallel(n_jobs=-1)(delayed(proc)(i) for i in range(10000))
total = sum(sub)

print(total)
print('並列処理', (time()-start), "秒")
# Out:
# 2499500025000000
# 並列処理 5.294717073440552 秒

# %%
# %%time
def proc(n):
    return sum([m * n for m in range(10000)])

sub = Parallel(n_jobs=-1)(delayed(proc)(i) for i in range(10000))
total = sum(sub)

print(total)
# Out:
# 2499500025000000
# Wall time: 4.69 s

# %%
pip install py7zr
# Out:
# Requirement already satisfied: py7zr in c:\users\genta212\anaconda3\lib\site-packages (0.16.1)
# Requirement already satisfied: pyzstd<0.15.0,>=0.14.4 in c:\users\genta212\anaconda3\lib\site-packages (from py7zr) (0.14.4)
# Requirement already satisfied: pyppmd>=0.14.0 in c:\users\genta212\anaconda3\lib\site-packages (from py7zr) (0.15.0)
# Requirement already satisfied: multivolumefile>=0.2.3 in c:\users\genta212\anaconda3\lib\site-packages (from py7zr) (0.2.3)
# Requirement already satisfied: pycryptodomex>=3.6.6 in c:\users\genta212\anaconda3\lib\site-packages (from py7zr) (3.10.1)
# Requirement already satisfied: texttable in c:\users\genta212\anaconda3\lib\site-packages (from py7zr) (1.6.3)
# Requirement already satisfied: brotli>=1.0.9 in c:\users\genta212\anaconda3\lib\site-packages (from py7zr) (1.0.9)
# Requirement already satisfied: bcj-cffi<0.6.0,>=0.5.1 in c:\users\genta212\anaconda3\lib\site-packages (from py7zr) (0.5.1)
# Requirement already satisfied: cffi>=1.14.0 in c:\users\genta212\anaconda3\lib\site-packages (from bcj-cffi<0.6.0,>=0.5.1->py7zr) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\genta212\anaconda3\lib\site-packages (from cffi>=1.14.0->bcj-cffi<0.6.0,>=0.5.1->py7zr) (2.20)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # check the aircon data

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\genta212\\practice'

# %%
# %%time
import py7zr

os.chdir("C:/Users/genta212/practice")
df = py7zr.unpack_7zarchive("練習用.7z", "practice")

print("decompress is finished") #1min 44s
#今の処理時間の120数倍かかるからなるべく高速化
# Out:
# decompress is finished
# Wall time: 1min 53s

# %%
# %%time
import pandas as pd
import gzip
import os

os.chdir("C:/Users/sugiyama/practice/copy")
pd.set_option("display.max_columns",100) 

with open("test2.csv", "a", newline="") as f:
    with gzip.open("201708010000_aircon_status_info_1.csv.gz", "rt") as t:
        data = t.read()
        print(data, file=f)

print(os.path.getsize("test2.csv")) #7749152byte=7.74MB
# Out:
# 3953008
# Wall time: 80.1 ms

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12242 entries, 0 to 12241
# Data columns (total 71 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   retrieve_date  12242 non-null  object
#  1   mac            12242 non-null  object
#  2   model          12242 non-null  object
#  3   pow            12242 non-null  bool
#  4   mode           12242 non-null  object
#  5   adv            12242 non-null  object
#  6   stemp          12242 non-null  object
#  7   shum           12242 non-null  object
#  8   alert          12240 non-null  float64
#  9   f_dir          12242 non-null  object
#  10  htemp          12242 non-null  float64
#  11  otemp          12242 non-null  float64
#  12  tap            12242 non-null  object
#  13  rawrtmp        12242 non-null  float64
#  14  humid          12215 non-null  float64
#  15  trtmp          12242 non-null  float64
#  16  fangl          12242 non-null  int64
#  17  hetmp          12242 non-null  float64
#  18  itelc          12215 non-null  float64
#  19  cmpfrq         12242 non-null  int64
#  20  gx00           11652 non-null  float64
#  21  gx01           11652 non-null  float64
#  22  gx02           11652 non-null  float64
#  23  gx03           11652 non-null  float64
#  24  gx04           11652 non-null  float64
#  25  gx05           12242 non-null  object
#  26  gx06           11652 non-null  float64
#  27  gx07           11652 non-null  float64
#  28  remcount       11652 non-null  float64
#  29  lasbutton      11652 non-null  float64
#  30  today_runtime  12242 non-null  int64
#  31  today_power    12242 non-null  int64
#  32  fan            12242 non-null  int64
#  33  operator       12242 non-null  object
#  34  stemp_a        12242 non-null  object
#  35  f_dir_ud       12242 non-null  object
#  36  f_dir_lr       12242 non-null  object
#  37  delta_h        0 non-null      float64
#  38  tgthum         0 non-null      float64
#  39  swid           0 non-null      float64
#  40  gx09           6831 non-null   float64
#  41  gx0a           6831 non-null   float64
#  42  gx0b           12242 non-null  object
#  43  gx0c           6831 non-null   float64
#  44  gx0d           12242 non-null  object
#  45  gx0e           12242 non-null  object
#  46  gx0f           12242 non-null  object
#  47  gx10           12242 non-null  object
#  48  gx11           12242 non-null  object
#  49  gx12           12242 non-null  object
#  50  gx13           12242 non-null  object
#  51  gx14           12242 non-null  object
#  52  target_pmv     0 non-null      float64
#  53  current_pmv    0 non-null      float64
#  54  gx16           0 non-null      float64
#  55  gx17           0 non-null      float64
#  56  gx18           12242 non-null  object
#  57  prod_model     0 non-null      float64
#  58  prod_site      12242 non-null  object
#  59  prod_line      12242 non-null  object
#  60  prod_order     12242 non-null  object
#  61  inp_site       12242 non-null  object
#  62  inp_base       12242 non-null  object
#  63  inp_dev        12242 non-null  object
#  64  inp_mdate      12242 non-null  object
#  65  inp_serial     12242 non-null  object
#  66  outp_site      12242 non-null  object
#  67  outp_base      12242 non-null  object
#  68  outp_dev       12242 non-null  object
#  69  outp_mdate     12242 non-null  object
#  70  outp_serial    12242 non-null  object
# dtypes: bool(1), float64(28), int64(5), object(37)
# memory usage: 6.5+ MB

# %% [markdown]
# # practice using by aircon data

# %% [markdown]
# ## copy gzip files that are included multiple folers to once folder

# %%
# copying gzip files that are included multiple folder to once folder 

from time import time
import os
import shutil
import glob

def copy_files(path):
    os.makedirs("copy", exist_ok=True)
    for curdir, subdir, subfile in os.walk(path, topdown=False):
        for file in subfile:
            file_path = os.path.join(curdir, file)
            try:
                shutil.copy(file_path, "copy")
            except Exception as err:
                print("発生したエラーの種類: {}".format(err))
                pass
                           
start = time()
os.chdir("C:/users/genta212/practice")
current_path = os.getcwd()

copy_files(current_path)
print("file copy is finished")
print('逐次処理', (time()-start), "秒") #逐次処理 73.7738618850708 秒
# Out:
# 発生したエラーの種類: 'C:\\users\\genta212\\practice\\copy\\practice_unzip&concat_aircondata-checkpoint.ipynb' and 'copy\\practice_unzip&concat_aircondata-checkpoint.ipynb' are the same file
# file copy is finished
# 逐次処理 73.7738618850708 秒

# %%
# copying gzip files that are included multiple folder to once folder(Parallel)

from time import time
import os
import shutil
import glob

def copy_para(curdir,subdir,subfile):
        for file in subfile:
            file_path = os.path.join(curdir, file)
            try:
                shutil.copy(file_path, "copy2")
            except Exception as err:
                print("発生したエラーの種類: {}".format(err))
                pass
                           
start = time()
os.chdir("C:/users/sugiyama/practice")
current_path = os.getcwd()
os.makedirs("copy2", exist_ok=True)

Parallel(n_jobs=-1)(delayed(copy_para)(curdir, subdir, subfile) for curdir, subdir, subfile in os.walk(current_path, topdown=False))

print("file copy is finished")
print('並列処理', (time()-start), "秒")#並列処理 329.5281240940094 秒
# Out:
# file copy is finished
# 並列処理 329.5281240940094 秒

# %% [markdown]
# ## decompress and concat all csv files

# %%
# decompress and concat .gz files at once
import os
import pandas as pd
import gzip
from time import time
import glob

start = time()

os.chdir("C:/Users/genta212/practice/copy")

gz_files = glob.glob("*.csv.gz")
with open("total.csv", "a", newline='') as f:
    for file in gz_files:
        with gzip.open(file, "rt") as t:
            next(t)
            data = t.read()
            print(data, file=f)
        
print("decompress is finished")
print('逐次処理', (time()-start), '秒') #逐次処理 508.65018010139465 秒, 34GB

#各ファイルのデータが1行にまとまってデータ数分の列ができてる＝バイナリーで１文で解凍されたデータがそのまま縦に結合されてる
#→ヘッダーを設定して改行して70列×数万行のCSVを作れるのが理想→テキスト形式で読み込んだら普通にできた。
#→各データのヘッダーを飛ばしてるので、再設定する必要がある。
#並列化による処理時間の短縮と欠損値の型変換によるデータ量の削減作業(np.)もやる
# Out:
# decompress is finished
# 逐次処理 508.65018010139465 秒

# %%
# decompress and concat .gz files at once(Parallel)

from joblib import Parallel, delayed
from time import time
import gzip
import glob
import os
from itertools import islice
import shutil

       
#リストを指定したチャンクサイズに分割
def group_elements(n, iterable, padvalue=""):
    return zip_longest(*[iter(iterable)]*n, fillvalue=padvalue)
        
        
#カレントディレクトリ以下のgzipファイルのリストを作成し指定数で分割したタプルを返す。
def gz_chunk_list(cwd_path, n):
    for curdir, subdir, subfile in os.walk(cwd_path, topdown=False):
        path_list = [os.path.join(curdir, file) for file in subfile]
        gz_chunks = [group_elements(n, iterable) for iterable in path_list]
    return gz_chunks
        

#同じ名前のファイル名が存在するかチェック
def duplicate_rename(file_path):
    if os.pat.exists(file_path): #存在した場合
        name, ext = os.path.splitext(file_path) #パスからファイル名と拡張子を分割」
        i = 1
        while True:
            new_name = "{}({:0=3}){}".format(name,i, ext) #数値を4桁にしたい場合は({:0=4})とする
            if not os.path.exitsts(new_name):
                return new_name
            i += 1
    
    else:
        return file_paths

        
#gzipを解凍・結合して別ディレクトリに集約
def decomp(**file_path):
    with gzip.open(file_path, "rt") as t:
        data = t.read()
    with open("./aircon_info_data(001).csv", "a", newline='') as f:
        print(data, file=f)
        
        file_path = f
        new_path = duplicate_rename(file_path)
        shutil.move(filePath, new_path)

        
start = time()

os.chdir("C:/Users/genta212/practice/practice/")
cwd_path = os.getcwd()

new_dirname = "C:/Users/genta212/practice/copy3"
os.makedirs(new_dirname, exist_ok=True)
moved_path = new_dirname

gz_chunks = gz_chunk_list(cwd_path, 10)

Parallel(n_jobs=-1)(delayed(decomp)(c) for c in gz_chunks)

print(gz_chunks)
print('decompress is finished')
print('並列処理', (time()-start), "秒") #並列処理 165.63339948654175 秒 21GB

#なんか結合はしてるけどデータが減ってる？ファイルの数が8928個で、上のコードはファイル数＝行数になってる。
#このコードだと5754行になって10GB以上サイズも違うのでなんか抜けてる可能性あり
# Out:
# []
# decompress is finished
# 並列処理 0.060547590255737305 秒
# '\n#辞書を指定したチャンクサイズに分割\ndef dict_chunks(data, size):\n    it = iter(data)\n    for i in range(0, len(data), size):\n        yield{k:data[k] for k in islice(it, size)}\n        \n        \n#現在のディレクトリ以下の全てのファイル名をキー、絶対パスを値とした辞書の作成\ndef mkdic(cwd_path):\n    for curdir, subdir, subfile in os.walk(path, topdown=False):\n        files_name = [i for i in subfile]\n        files_path = [os.path.join(curdir, file) for file in subfile]\n        gz_dict = dict(zip(files_name, files_path))\n        return gz_dict\n        \n\n#以下参考コード(散乱したファイルの移動・集約）←上の処理に組み込んで省略予定\ndef copy_files(path):\n    os.makedirs("copy", exist_ok=True)\n    for curdir, subdir, subfile in os.walk(path, topdown=False):\n        for file in subfile:\n            file_path = os.path.join(curdir, file)\n            try:\n                shutil.copy(file_path, "copy")\n            except Exception as err:\n                print("発生したエラーの種類: {}".format(err))\n                pass\n\n\nstart = time()\nos.chdir("C:/users/genta212/practice")\ncurrent_path = os.getcwd()\n\ncopy_files(current_path)\nprint("file copy is finished")\nprint(\'逐次処理\', (time()-start), "秒") #逐次処理 73.7738618850708 秒\n'

# %%
import gzip
import os
import glob
from pathlib import Path

os.chdir("C:/Users/genta212/practice/practice/")
path = os.getcwd()

for curdir, subdir, subfile in os.walk(path, topdown=False):
    files_name = [i for i in subfile]
    files_path = [os.path.join(curdir, file) for file in subfile]
    gz_dict = dict(zip(files_name, files_path))
    print(gz_dict)
# Out:
# {'201708010000_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170801\\201708010000_aircon_status_info_1.csv.gz', '201708010005_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170801\\201708010005_aircon_status_info_2.csv.gz', '201708010010_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170801\\201708010010_aircon_status_info_1.csv.gz', '201708010015_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170801\\201708010015_aircon_status_info_2.csv.gz', '201708010020_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170801\\201708010020_aircon_status_info_1.csv.gz', '201708010025_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170801\\201708010025_aircon_status_info_2.csv.gz', '201708010030_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170801\\201708010030_aircon_status_info_1.csv.gz', '201708010035_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170801\\201708010035_aircon_status_info_2.csv.gz', '201708010040_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170801\\201708010040_aircon_status_info_1.csv.gz', '201708010045_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170801\\201708010045_aircon_status_info_2.csv.gz', '201708010050_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170801\\201708010050_aircon_status_info_1.csv.gz', '201708010055_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170801\\201708010055_aircon_status_info_2.csv.gz', '201708010100_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170801\\201708010100_aircon_status_info_1.csv.gz', '201708010105_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170801\\201708010105_aircon_status_info_2.csv.gz', '201708010110_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170801\\201708010110_aircon_status_info_1.csv.gz', '201708010115_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170801\\201708010115_aircon_status_info_2.csv.gz', '201708010120_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170801\\201708010120_aircon_status_info_1.csv.gz', '201708010125_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170801\\201708010125_aircon_status_info_2.csv.gz', '201708010130_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170801\\201708010130_aircon_status_info_1.csv.gz', '201708010135_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170801\\201708010135_aircon_status_info_2.csv.gz', '201708010140_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170801\\201708010140_aircon_status_info_1.csv.gz', '201708010145_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170801\\201708010145_aircon_status_info_2.csv.gz', '201708010150_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170801\\201708010150_aircon_status_info_1.csv.gz', '201708010155_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170801\\201708010155_aircon_status_info_2.csv.gz', '201708010200_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170801\\201708010200_aircon_status_info_1.csv.gz', '201708010205_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170801\\201708010205_aircon_status_info_2.csv.gz', '201708010210_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170801\\201708010210_aircon_status_info_1.csv.gz', '201708010215_aircon_status_in ...
# {'201708020000_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170802\\201708020000_aircon_status_info_1.csv.gz', '201708020005_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170802\\201708020005_aircon_status_info_2.csv.gz', '201708020010_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170802\\201708020010_aircon_status_info_1.csv.gz', '201708020015_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170802\\201708020015_aircon_status_info_2.csv.gz', '201708020020_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170802\\201708020020_aircon_status_info_1.csv.gz', '201708020025_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170802\\201708020025_aircon_status_info_2.csv.gz', '201708020030_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170802\\201708020030_aircon_status_info_1.csv.gz', '201708020035_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170802\\201708020035_aircon_status_info_2.csv.gz', '201708020040_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170802\\201708020040_aircon_status_info_1.csv.gz', '201708020045_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170802\\201708020045_aircon_status_info_2.csv.gz', '201708020050_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170802\\201708020050_aircon_status_info_1.csv.gz', '201708020055_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170802\\201708020055_aircon_status_info_2.csv.gz', '201708020100_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170802\\201708020100_aircon_status_info_1.csv.gz', '201708020105_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170802\\201708020105_aircon_status_info_2.csv.gz', '201708020110_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170802\\201708020110_aircon_status_info_1.csv.gz', '201708020115_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170802\\201708020115_aircon_status_info_2.csv.gz', '201708020120_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170802\\201708020120_aircon_status_info_1.csv.gz', '201708020125_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170802\\201708020125_aircon_status_info_2.csv.gz', '201708020130_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170802\\201708020130_aircon_status_info_1.csv.gz', '201708020135_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170802\\201708020135_aircon_status_info_2.csv.gz', '201708020140_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170802\\201708020140_aircon_status_info_1.csv.gz', '201708020145_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170802\\201708020145_aircon_status_info_2.csv.gz', '201708020150_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170802\\201708020150_aircon_status_info_1.csv.gz', '201708020155_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170802\\201708020155_aircon_status_info_2.csv.gz', '201708020200_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170802\\201708020200_aircon_status_info_1.csv.gz', '201708020205_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170802\\201708020205_aircon_status_info_2.csv.gz', '201708020210_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170802\\201708020210_aircon_status_info_1.csv.gz', '201708020215_aircon_status_in ...
# {'201708030000_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170803\\201708030000_aircon_status_info_1.csv.gz', '201708030005_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170803\\201708030005_aircon_status_info_2.csv.gz', '201708030010_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170803\\201708030010_aircon_status_info_1.csv.gz', '201708030015_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170803\\201708030015_aircon_status_info_2.csv.gz', '201708030020_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170803\\201708030020_aircon_status_info_1.csv.gz', '201708030025_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170803\\201708030025_aircon_status_info_2.csv.gz', '201708030030_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170803\\201708030030_aircon_status_info_1.csv.gz', '201708030035_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170803\\201708030035_aircon_status_info_2.csv.gz', '201708030040_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170803\\201708030040_aircon_status_info_1.csv.gz', '201708030045_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170803\\201708030045_aircon_status_info_2.csv.gz', '201708030050_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170803\\201708030050_aircon_status_info_1.csv.gz', '201708030055_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170803\\201708030055_aircon_status_info_2.csv.gz', '201708030100_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170803\\201708030100_aircon_status_info_1.csv.gz', '201708030105_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170803\\201708030105_aircon_status_info_2.csv.gz', '201708030110_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170803\\201708030110_aircon_status_info_1.csv.gz', '201708030115_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170803\\201708030115_aircon_status_info_2.csv.gz', '201708030120_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170803\\201708030120_aircon_status_info_1.csv.gz', '201708030125_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170803\\201708030125_aircon_status_info_2.csv.gz', '201708030130_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170803\\201708030130_aircon_status_info_1.csv.gz', '201708030135_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170803\\201708030135_aircon_status_info_2.csv.gz', '201708030140_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170803\\201708030140_aircon_status_info_1.csv.gz', '201708030145_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170803\\201708030145_aircon_status_info_2.csv.gz', '201708030150_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170803\\201708030150_aircon_status_info_1.csv.gz', '201708030155_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170803\\201708030155_aircon_status_info_2.csv.gz', '201708030200_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170803\\201708030200_aircon_status_info_1.csv.gz', '201708030205_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170803\\201708030205_aircon_status_info_2.csv.gz', '201708030210_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170803\\201708030210_aircon_status_info_1.csv.gz', '201708030215_aircon_status_in ...
# {'201708040000_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170804\\201708040000_aircon_status_info_1.csv.gz', '201708040005_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170804\\201708040005_aircon_status_info_2.csv.gz', '201708040010_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170804\\201708040010_aircon_status_info_1.csv.gz', '201708040015_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170804\\201708040015_aircon_status_info_2.csv.gz', '201708040020_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170804\\201708040020_aircon_status_info_1.csv.gz', '201708040025_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170804\\201708040025_aircon_status_info_2.csv.gz', '201708040030_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170804\\201708040030_aircon_status_info_1.csv.gz', '201708040035_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170804\\201708040035_aircon_status_info_2.csv.gz', '201708040040_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170804\\201708040040_aircon_status_info_1.csv.gz', '201708040045_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170804\\201708040045_aircon_status_info_2.csv.gz', '201708040050_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170804\\201708040050_aircon_status_info_1.csv.gz', '201708040055_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170804\\201708040055_aircon_status_info_2.csv.gz', '201708040100_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170804\\201708040100_aircon_status_info_1.csv.gz', '201708040105_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170804\\201708040105_aircon_status_info_2.csv.gz', '201708040110_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170804\\201708040110_aircon_status_info_1.csv.gz', '201708040115_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170804\\201708040115_aircon_status_info_2.csv.gz', '201708040120_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170804\\201708040120_aircon_status_info_1.csv.gz', '201708040125_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170804\\201708040125_aircon_status_info_2.csv.gz', '201708040130_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170804\\201708040130_aircon_status_info_1.csv.gz', '201708040135_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170804\\201708040135_aircon_status_info_2.csv.gz', '201708040140_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170804\\201708040140_aircon_status_info_1.csv.gz', '201708040145_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170804\\201708040145_aircon_status_info_2.csv.gz', '201708040150_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170804\\201708040150_aircon_status_info_1.csv.gz', '201708040155_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170804\\201708040155_aircon_status_info_2.csv.gz', '201708040200_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170804\\201708040200_aircon_status_info_1.csv.gz', '201708040205_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170804\\201708040205_aircon_status_info_2.csv.gz', '201708040210_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170804\\201708040210_aircon_status_info_1.csv.gz', '201708040215_aircon_status_in ...
# {'201708050000_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170805\\201708050000_aircon_status_info_1.csv.gz', '201708050005_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170805\\201708050005_aircon_status_info_2.csv.gz', '201708050010_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170805\\201708050010_aircon_status_info_1.csv.gz', '201708050015_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170805\\201708050015_aircon_status_info_2.csv.gz', '201708050020_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170805\\201708050020_aircon_status_info_1.csv.gz', '201708050025_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170805\\201708050025_aircon_status_info_2.csv.gz', '201708050030_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170805\\201708050030_aircon_status_info_1.csv.gz', '201708050035_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170805\\201708050035_aircon_status_info_2.csv.gz', '201708050040_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170805\\201708050040_aircon_status_info_1.csv.gz', '201708050045_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170805\\201708050045_aircon_status_info_2.csv.gz', '201708050050_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170805\\201708050050_aircon_status_info_1.csv.gz', '201708050055_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170805\\201708050055_aircon_status_info_2.csv.gz', '201708050100_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170805\\201708050100_aircon_status_info_1.csv.gz', '201708050105_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170805\\201708050105_aircon_status_info_2.csv.gz', '201708050110_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170805\\201708050110_aircon_status_info_1.csv.gz', '201708050115_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170805\\201708050115_aircon_status_info_2.csv.gz', '201708050120_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170805\\201708050120_aircon_status_info_1.csv.gz', '201708050125_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170805\\201708050125_aircon_status_info_2.csv.gz', '201708050130_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170805\\201708050130_aircon_status_info_1.csv.gz', '201708050135_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170805\\201708050135_aircon_status_info_2.csv.gz', '201708050140_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170805\\201708050140_aircon_status_info_1.csv.gz', '201708050145_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170805\\201708050145_aircon_status_info_2.csv.gz', '201708050150_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170805\\201708050150_aircon_status_info_1.csv.gz', '201708050155_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170805\\201708050155_aircon_status_info_2.csv.gz', '201708050200_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170805\\201708050200_aircon_status_info_1.csv.gz', '201708050205_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170805\\201708050205_aircon_status_info_2.csv.gz', '201708050210_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170805\\201708050210_aircon_status_info_1.csv.gz', '201708050215_aircon_status_in ...
# {'201708060000_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170806\\201708060000_aircon_status_info_1.csv.gz', '201708060005_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170806\\201708060005_aircon_status_info_2.csv.gz', '201708060010_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170806\\201708060010_aircon_status_info_1.csv.gz', '201708060015_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170806\\201708060015_aircon_status_info_2.csv.gz', '201708060020_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170806\\201708060020_aircon_status_info_1.csv.gz', '201708060025_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170806\\201708060025_aircon_status_info_2.csv.gz', '201708060030_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170806\\201708060030_aircon_status_info_1.csv.gz', '201708060035_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170806\\201708060035_aircon_status_info_2.csv.gz', '201708060040_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170806\\201708060040_aircon_status_info_1.csv.gz', '201708060045_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170806\\201708060045_aircon_status_info_2.csv.gz', '201708060050_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170806\\201708060050_aircon_status_info_1.csv.gz', '201708060055_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170806\\201708060055_aircon_status_info_2.csv.gz', '201708060100_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170806\\201708060100_aircon_status_info_1.csv.gz', '201708060105_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170806\\201708060105_aircon_status_info_2.csv.gz', '201708060110_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170806\\201708060110_aircon_status_info_1.csv.gz', '201708060115_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170806\\201708060115_aircon_status_info_2.csv.gz', '201708060120_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170806\\201708060120_aircon_status_info_1.csv.gz', '201708060125_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170806\\201708060125_aircon_status_info_2.csv.gz', '201708060130_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170806\\201708060130_aircon_status_info_1.csv.gz', '201708060135_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170806\\201708060135_aircon_status_info_2.csv.gz', '201708060140_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170806\\201708060140_aircon_status_info_1.csv.gz', '201708060145_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170806\\201708060145_aircon_status_info_2.csv.gz', '201708060150_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170806\\201708060150_aircon_status_info_1.csv.gz', '201708060155_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170806\\201708060155_aircon_status_info_2.csv.gz', '201708060200_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170806\\201708060200_aircon_status_info_1.csv.gz', '201708060205_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170806\\201708060205_aircon_status_info_2.csv.gz', '201708060210_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170806\\201708060210_aircon_status_info_1.csv.gz', '201708060215_aircon_status_in ...
# {'201708070000_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170807\\201708070000_aircon_status_info_1.csv.gz', '201708070005_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170807\\201708070005_aircon_status_info_2.csv.gz', '201708070010_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170807\\201708070010_aircon_status_info_1.csv.gz', '201708070015_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170807\\201708070015_aircon_status_info_2.csv.gz', '201708070020_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170807\\201708070020_aircon_status_info_1.csv.gz', '201708070025_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170807\\201708070025_aircon_status_info_2.csv.gz', '201708070030_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170807\\201708070030_aircon_status_info_1.csv.gz', '201708070035_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170807\\201708070035_aircon_status_info_2.csv.gz', '201708070040_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170807\\201708070040_aircon_status_info_1.csv.gz', '201708070045_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170807\\201708070045_aircon_status_info_2.csv.gz', '201708070050_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170807\\201708070050_aircon_status_info_1.csv.gz', '201708070055_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170807\\201708070055_aircon_status_info_2.csv.gz', '201708070100_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170807\\201708070100_aircon_status_info_1.csv.gz', '201708070105_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170807\\201708070105_aircon_status_info_2.csv.gz', '201708070110_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170807\\201708070110_aircon_status_info_1.csv.gz', '201708070115_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170807\\201708070115_aircon_status_info_2.csv.gz', '201708070120_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170807\\201708070120_aircon_status_info_1.csv.gz', '201708070125_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170807\\201708070125_aircon_status_info_2.csv.gz', '201708070130_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170807\\201708070130_aircon_status_info_1.csv.gz', '201708070135_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170807\\201708070135_aircon_status_info_2.csv.gz', '201708070140_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170807\\201708070140_aircon_status_info_1.csv.gz', '201708070145_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170807\\201708070145_aircon_status_info_2.csv.gz', '201708070150_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170807\\201708070150_aircon_status_info_1.csv.gz', '201708070155_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170807\\201708070155_aircon_status_info_2.csv.gz', '201708070200_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170807\\201708070200_aircon_status_info_1.csv.gz', '201708070205_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170807\\201708070205_aircon_status_info_2.csv.gz', '201708070210_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170807\\201708070210_aircon_status_info_1.csv.gz', '201708070215_aircon_status_in ...
# {'201708080000_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170808\\201708080000_aircon_status_info_1.csv.gz', '201708080005_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170808\\201708080005_aircon_status_info_2.csv.gz', '201708080010_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170808\\201708080010_aircon_status_info_1.csv.gz', '201708080015_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170808\\201708080015_aircon_status_info_2.csv.gz', '201708080020_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170808\\201708080020_aircon_status_info_1.csv.gz', '201708080025_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170808\\201708080025_aircon_status_info_2.csv.gz', '201708080030_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170808\\201708080030_aircon_status_info_1.csv.gz', '201708080035_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170808\\201708080035_aircon_status_info_2.csv.gz', '201708080040_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170808\\201708080040_aircon_status_info_1.csv.gz', '201708080045_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170808\\201708080045_aircon_status_info_2.csv.gz', '201708080050_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170808\\201708080050_aircon_status_info_1.csv.gz', '201708080055_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170808\\201708080055_aircon_status_info_2.csv.gz', '201708080100_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170808\\201708080100_aircon_status_info_1.csv.gz', '201708080105_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170808\\201708080105_aircon_status_info_2.csv.gz', '201708080110_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170808\\201708080110_aircon_status_info_1.csv.gz', '201708080115_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170808\\201708080115_aircon_status_info_2.csv.gz', '201708080120_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170808\\201708080120_aircon_status_info_1.csv.gz', '201708080125_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170808\\201708080125_aircon_status_info_2.csv.gz', '201708080130_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170808\\201708080130_aircon_status_info_1.csv.gz', '201708080135_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170808\\201708080135_aircon_status_info_2.csv.gz', '201708080140_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170808\\201708080140_aircon_status_info_1.csv.gz', '201708080145_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170808\\201708080145_aircon_status_info_2.csv.gz', '201708080150_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170808\\201708080150_aircon_status_info_1.csv.gz', '201708080155_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170808\\201708080155_aircon_status_info_2.csv.gz', '201708080200_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170808\\201708080200_aircon_status_info_1.csv.gz', '201708080205_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170808\\201708080205_aircon_status_info_2.csv.gz', '201708080210_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170808\\201708080210_aircon_status_info_1.csv.gz', '201708080215_aircon_status_in ...
# {'201708090000_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170809\\201708090000_aircon_status_info_1.csv.gz', '201708090005_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170809\\201708090005_aircon_status_info_2.csv.gz', '201708090010_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170809\\201708090010_aircon_status_info_1.csv.gz', '201708090015_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170809\\201708090015_aircon_status_info_2.csv.gz', '201708090020_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170809\\201708090020_aircon_status_info_1.csv.gz', '201708090025_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170809\\201708090025_aircon_status_info_2.csv.gz', '201708090030_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170809\\201708090030_aircon_status_info_1.csv.gz', '201708090035_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170809\\201708090035_aircon_status_info_2.csv.gz', '201708090040_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170809\\201708090040_aircon_status_info_1.csv.gz', '201708090045_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170809\\201708090045_aircon_status_info_2.csv.gz', '201708090050_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170809\\201708090050_aircon_status_info_1.csv.gz', '201708090055_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170809\\201708090055_aircon_status_info_2.csv.gz', '201708090100_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170809\\201708090100_aircon_status_info_1.csv.gz', '201708090105_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170809\\201708090105_aircon_status_info_2.csv.gz', '201708090110_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170809\\201708090110_aircon_status_info_1.csv.gz', '201708090115_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170809\\201708090115_aircon_status_info_2.csv.gz', '201708090120_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170809\\201708090120_aircon_status_info_1.csv.gz', '201708090125_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170809\\201708090125_aircon_status_info_2.csv.gz', '201708090130_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170809\\201708090130_aircon_status_info_1.csv.gz', '201708090135_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170809\\201708090135_aircon_status_info_2.csv.gz', '201708090140_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170809\\201708090140_aircon_status_info_1.csv.gz', '201708090145_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170809\\201708090145_aircon_status_info_2.csv.gz', '201708090150_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170809\\201708090150_aircon_status_info_1.csv.gz', '201708090155_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170809\\201708090155_aircon_status_info_2.csv.gz', '201708090200_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170809\\201708090200_aircon_status_info_1.csv.gz', '201708090205_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170809\\201708090205_aircon_status_info_2.csv.gz', '201708090210_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170809\\201708090210_aircon_status_info_1.csv.gz', '201708090215_aircon_status_in ...
# {'201708100000_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170810\\201708100000_aircon_status_info_1.csv.gz', '201708100005_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170810\\201708100005_aircon_status_info_2.csv.gz', '201708100010_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170810\\201708100010_aircon_status_info_1.csv.gz', '201708100015_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170810\\201708100015_aircon_status_info_2.csv.gz', '201708100020_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170810\\201708100020_aircon_status_info_1.csv.gz', '201708100025_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170810\\201708100025_aircon_status_info_2.csv.gz', '201708100030_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170810\\201708100030_aircon_status_info_1.csv.gz', '201708100035_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170810\\201708100035_aircon_status_info_2.csv.gz', '201708100040_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170810\\201708100040_aircon_status_info_1.csv.gz', '201708100045_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170810\\201708100045_aircon_status_info_2.csv.gz', '201708100050_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170810\\201708100050_aircon_status_info_1.csv.gz', '201708100055_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170810\\201708100055_aircon_status_info_2.csv.gz', '201708100100_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170810\\201708100100_aircon_status_info_1.csv.gz', '201708100105_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170810\\201708100105_aircon_status_info_2.csv.gz', '201708100110_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170810\\201708100110_aircon_status_info_1.csv.gz', '201708100115_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170810\\201708100115_aircon_status_info_2.csv.gz', '201708100120_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170810\\201708100120_aircon_status_info_1.csv.gz', '201708100125_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170810\\201708100125_aircon_status_info_2.csv.gz', '201708100130_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170810\\201708100130_aircon_status_info_1.csv.gz', '201708100135_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170810\\201708100135_aircon_status_info_2.csv.gz', '201708100140_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170810\\201708100140_aircon_status_info_1.csv.gz', '201708100145_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170810\\201708100145_aircon_status_info_2.csv.gz', '201708100150_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170810\\201708100150_aircon_status_info_1.csv.gz', '201708100155_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170810\\201708100155_aircon_status_info_2.csv.gz', '201708100200_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170810\\201708100200_aircon_status_info_1.csv.gz', '201708100205_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170810\\201708100205_aircon_status_info_2.csv.gz', '201708100210_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170810\\201708100210_aircon_status_info_1.csv.gz', '201708100215_aircon_status_in ...
# {'201708110000_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170811\\201708110000_aircon_status_info_1.csv.gz', '201708110005_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170811\\201708110005_aircon_status_info_2.csv.gz', '201708110010_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170811\\201708110010_aircon_status_info_1.csv.gz', '201708110015_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170811\\201708110015_aircon_status_info_2.csv.gz', '201708110020_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170811\\201708110020_aircon_status_info_1.csv.gz', '201708110025_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170811\\201708110025_aircon_status_info_2.csv.gz', '201708110030_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170811\\201708110030_aircon_status_info_1.csv.gz', '201708110035_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170811\\201708110035_aircon_status_info_2.csv.gz', '201708110040_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170811\\201708110040_aircon_status_info_1.csv.gz', '201708110045_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170811\\201708110045_aircon_status_info_2.csv.gz', '201708110050_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170811\\201708110050_aircon_status_info_1.csv.gz', '201708110055_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170811\\201708110055_aircon_status_info_2.csv.gz', '201708110100_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170811\\201708110100_aircon_status_info_1.csv.gz', '201708110105_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170811\\201708110105_aircon_status_info_2.csv.gz', '201708110110_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170811\\201708110110_aircon_status_info_1.csv.gz', '201708110115_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170811\\201708110115_aircon_status_info_2.csv.gz', '201708110120_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170811\\201708110120_aircon_status_info_1.csv.gz', '201708110125_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170811\\201708110125_aircon_status_info_2.csv.gz', '201708110130_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170811\\201708110130_aircon_status_info_1.csv.gz', '201708110135_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170811\\201708110135_aircon_status_info_2.csv.gz', '201708110140_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170811\\201708110140_aircon_status_info_1.csv.gz', '201708110145_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170811\\201708110145_aircon_status_info_2.csv.gz', '201708110150_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170811\\201708110150_aircon_status_info_1.csv.gz', '201708110155_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170811\\201708110155_aircon_status_info_2.csv.gz', '201708110200_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170811\\201708110200_aircon_status_info_1.csv.gz', '201708110205_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170811\\201708110205_aircon_status_info_2.csv.gz', '201708110210_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170811\\201708110210_aircon_status_info_1.csv.gz', '201708110215_aircon_status_in ...
# ...
# {'201708290000_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170829\\201708290000_aircon_status_info_1.csv.gz', '201708290005_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170829\\201708290005_aircon_status_info_2.csv.gz', '201708290010_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170829\\201708290010_aircon_status_info_1.csv.gz', '201708290015_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170829\\201708290015_aircon_status_info_2.csv.gz', '201708290020_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170829\\201708290020_aircon_status_info_1.csv.gz', '201708290025_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170829\\201708290025_aircon_status_info_2.csv.gz', '201708290030_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170829\\201708290030_aircon_status_info_1.csv.gz', '201708290035_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170829\\201708290035_aircon_status_info_2.csv.gz', '201708290040_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170829\\201708290040_aircon_status_info_1.csv.gz', '201708290045_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170829\\201708290045_aircon_status_info_2.csv.gz', '201708290050_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170829\\201708290050_aircon_status_info_1.csv.gz', '201708290055_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170829\\201708290055_aircon_status_info_2.csv.gz', '201708290100_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170829\\201708290100_aircon_status_info_1.csv.gz', '201708290105_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170829\\201708290105_aircon_status_info_2.csv.gz', '201708290110_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170829\\201708290110_aircon_status_info_1.csv.gz', '201708290115_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170829\\201708290115_aircon_status_info_2.csv.gz', '201708290120_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170829\\201708290120_aircon_status_info_1.csv.gz', '201708290125_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170829\\201708290125_aircon_status_info_2.csv.gz', '201708290130_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170829\\201708290130_aircon_status_info_1.csv.gz', '201708290135_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170829\\201708290135_aircon_status_info_2.csv.gz', '201708290140_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170829\\201708290140_aircon_status_info_1.csv.gz', '201708290145_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170829\\201708290145_aircon_status_info_2.csv.gz', '201708290150_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170829\\201708290150_aircon_status_info_1.csv.gz', '201708290155_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170829\\201708290155_aircon_status_info_2.csv.gz', '201708290200_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170829\\201708290200_aircon_status_info_1.csv.gz', '201708290205_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170829\\201708290205_aircon_status_info_2.csv.gz', '201708290210_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170829\\201708290210_aircon_status_info_1.csv.gz', '201708290215_aircon_status_in ...
# {'201708300000_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170830\\201708300000_aircon_status_info_1.csv.gz', '201708300005_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170830\\201708300005_aircon_status_info_2.csv.gz', '201708300010_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170830\\201708300010_aircon_status_info_1.csv.gz', '201708300015_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170830\\201708300015_aircon_status_info_2.csv.gz', '201708300020_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170830\\201708300020_aircon_status_info_1.csv.gz', '201708300025_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170830\\201708300025_aircon_status_info_2.csv.gz', '201708300030_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170830\\201708300030_aircon_status_info_1.csv.gz', '201708300035_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170830\\201708300035_aircon_status_info_2.csv.gz', '201708300040_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170830\\201708300040_aircon_status_info_1.csv.gz', '201708300045_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170830\\201708300045_aircon_status_info_2.csv.gz', '201708300050_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170830\\201708300050_aircon_status_info_1.csv.gz', '201708300055_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170830\\201708300055_aircon_status_info_2.csv.gz', '201708300100_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170830\\201708300100_aircon_status_info_1.csv.gz', '201708300105_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170830\\201708300105_aircon_status_info_2.csv.gz', '201708300110_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170830\\201708300110_aircon_status_info_1.csv.gz', '201708300115_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170830\\201708300115_aircon_status_info_2.csv.gz', '201708300120_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170830\\201708300120_aircon_status_info_1.csv.gz', '201708300125_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170830\\201708300125_aircon_status_info_2.csv.gz', '201708300130_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170830\\201708300130_aircon_status_info_1.csv.gz', '201708300135_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170830\\201708300135_aircon_status_info_2.csv.gz', '201708300140_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170830\\201708300140_aircon_status_info_1.csv.gz', '201708300145_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170830\\201708300145_aircon_status_info_2.csv.gz', '201708300150_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170830\\201708300150_aircon_status_info_1.csv.gz', '201708300155_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170830\\201708300155_aircon_status_info_2.csv.gz', '201708300200_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170830\\201708300200_aircon_status_info_1.csv.gz', '201708300205_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170830\\201708300205_aircon_status_info_2.csv.gz', '201708300210_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170830\\201708300210_aircon_status_info_1.csv.gz', '201708300215_aircon_status_in ...
# {'201708310000_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170831\\201708310000_aircon_status_info_1.csv.gz', '201708310005_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170831\\201708310005_aircon_status_info_2.csv.gz', '201708310010_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170831\\201708310010_aircon_status_info_1.csv.gz', '201708310015_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170831\\201708310015_aircon_status_info_2.csv.gz', '201708310020_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170831\\201708310020_aircon_status_info_1.csv.gz', '201708310025_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170831\\201708310025_aircon_status_info_2.csv.gz', '201708310030_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170831\\201708310030_aircon_status_info_1.csv.gz', '201708310035_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170831\\201708310035_aircon_status_info_2.csv.gz', '201708310040_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170831\\201708310040_aircon_status_info_1.csv.gz', '201708310045_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170831\\201708310045_aircon_status_info_2.csv.gz', '201708310050_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170831\\201708310050_aircon_status_info_1.csv.gz', '201708310055_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170831\\201708310055_aircon_status_info_2.csv.gz', '201708310100_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170831\\201708310100_aircon_status_info_1.csv.gz', '201708310105_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170831\\201708310105_aircon_status_info_2.csv.gz', '201708310110_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170831\\201708310110_aircon_status_info_1.csv.gz', '201708310115_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170831\\201708310115_aircon_status_info_2.csv.gz', '201708310120_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170831\\201708310120_aircon_status_info_1.csv.gz', '201708310125_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170831\\201708310125_aircon_status_info_2.csv.gz', '201708310130_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170831\\201708310130_aircon_status_info_1.csv.gz', '201708310135_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170831\\201708310135_aircon_status_info_2.csv.gz', '201708310140_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170831\\201708310140_aircon_status_info_1.csv.gz', '201708310145_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170831\\201708310145_aircon_status_info_2.csv.gz', '201708310150_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170831\\201708310150_aircon_status_info_1.csv.gz', '201708310155_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170831\\201708310155_aircon_status_info_2.csv.gz', '201708310200_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170831\\201708310200_aircon_status_info_1.csv.gz', '201708310205_aircon_status_info_2.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170831\\201708310205_aircon_status_info_2.csv.gz', '201708310210_aircon_status_info_1.csv.gz': 'C:\\Users\\genta212\\practice\\practice\\201708\\20170831\\201708310210_aircon_status_info_1.csv.gz', '201708310215_aircon_status_in ...
# {}
# {}

# %%
import os
import re
import shutil

file_path = 'C:/Users/genta212/practice'

#同じ名前のファイル名が存在するかチェック
def duplicate_rename(file_path):
    if os.pat.exists(file_path): #存在した場合
        name, ext = os.path.splitext(file_path) #パスからファイル名と拡張子を分割」
        i = 1
        while True:
            #数値を3桁にしたい場合は({:0=3})とする
            new_name = "{}({:0=3}){}".format(name,i, ext)
            if not os.path.exitsts(new_name):
                return new_name
            i += 1
    
    else:
        return file_path
    
new_path = duplicate_rename(file_path)

shutil.move(file_path, new_path)

# %% [markdown]
# ## To import concating csv data to database(SQL)

# %%
# practice of connecting SQLite database
import sqlite3

db_path = "C:/Users/sugiyama/practice/test.db"
conn = sqlite3.connect(db_path)
conn.close()

# %%
# want to import all csv which include each directry to SQLite

import os
from os.path import join, split
from glob import glob

os.chdir("C:/Users/sugiyama/practice/practice/201708/201700801")
gz0_files =glob.glob("*.gz") for file in zip_files:
    with gzip.open(file, mode="rb") as fp:
        fp.extractall()

csv_path = r"C:/Users/sugiyama/practice/practice/201708/20170801"
db_path = r"C:/Users/sugiyama/practice/test.db"

def insert_csv():
    # csv ファイルのディレクトリ取得
    csv_files = glob(join(csv_path, "*.csv"))
    
    for csv in csv_files:
        table_name = split(csv)[1] # テーブル名作成
        table_name = table_name[0:-4] # テーブル名から拡張子を削除
        df = pd.read_csv(csv, dtype=object) # CSV読み込み
        with sqlite3.connect(db_path) as conn:
            df.to_sql(table_name, con=conn) # SQLiteにCSVをインポート

if __name__ == '__main__':
    insert_csv()
# Out:
#   File "<ipython-input-40-6e2c6ffc87c3>", line 7
#     gz0_files =glob.glob("*.gz") for file in zip_files:
#                                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 以下没コード

# %%
import glob
import pandas as pd
from time import time
import gzip
import os

start = time()

os.chdir("C:/Users/sugiyama/practice/copy")

# 同じフォルダのCSVファイルの一覧を取得
files = glob.glob('*.gz')

# gzファイルの数を取得
file_number = len(files) #8928

# gzファイルを解凍しつつ、欠損値を置換したcsvを順次結合
df0 = None
for file in files:
    df = pd.read_csv(file, sep=" ", na_values="None")
    if df0 is None:
        df0 = df
    else:
        df0 = dd.concat([df0,df])
  

# CSVファイルとして出力
df0.to_csv('merge.csv', encoding='utf_8',index=False)

# 結合完了のメッセージ
print(file_number,' 個のCSVファイルを結合して、merge.csvを作成しました。')

print('逐次処理', (time()-start), '秒')

#pdでdfとして解凍して都度結合してるからメモリに乗りきらずMemory Error、できても時間がかかりすぎる
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-d95b073bbaef> in <module>
#      23         df0 = df
#      24     else:
# ---> 25         df0 = dd.concat([df0,df])
#      26
#      27
#
# ~\anaconda3\lib\site-packages\dask\dataframe\multi.py in concat(dfs, axis, join, interleave_partitions, ignore_unknown_divisions, **kwargs)
#    1123         else:
#    1124             divisions = [None] * (sum([df.npartitions for df in dfs]) + 1)
# -> 1125             return stack_partitions(dfs, divisions, join=join, **kwargs)
#
# ~\anaconda3\lib\site-packages\dask\dataframe\multi.py in stack_partitions(dfs, divisions, join, **kwargs)
#     948         else:
#     949             pass  # TODO: there are other non-covered cases here
# --> 950         dsk.update(df.dask)
#     951         # An error will be raised if the schemas or categories don't match. In
#     952         # this case we need to pass along the meta object to transform each
#
# ~\anaconda3\lib\site-packages\dask\highlevelgraph.py in keys(self)
#     209
#     210     def keys(self):
# --> 211         return [key for key, _ in self.items()]
#     212
#     213     def values(self):
#
# ~\anaconda3\lib\site-packages\dask\highlevelgraph.py in items(self)
#     202                 if key not in seen:
#     203                     seen.add(key)
# --> 204                     items.append((key, d[key]))
#     205         return items
#     206
#
# KeyboardInterrupt:

# %%
# decompress and concat .gz files at once(multiprocessing)

from joblib import Parallel, delayed
from time import time
import gzip
import glob
from multiprocessing import Process
import os

def decomp(file):
    with gzip.open(file, "rt") as t:
        data = t.read()
    with open("total2.csv", "a", newline='') as f:
        print(data, file=f)

if __name__ == "__main__":
    os.chdir("C:/Users/genta212/practice/copy")
    
    start = time()

    gz_files = glob.glob("*.gz")
    p = Process(target=decomp, args=gz_files)

    p.start()
    print("Process started.")

    p.join()

    print('decompress is finished')
    print('並列処理', (time()-start), "秒") #並列処理  秒 GB

# %%
# decompress and concat .gz files at once(multiprocessing)

from joblib import Parallel, delayed
from time import time
import gzip
import glob
from multiprocessing import Pool
import os

os.chdir("C:/Users/genta212/practice/copy")

def decomp(file):
    with gzip.open(file, "rt") as t:
        data = t.read()
    with open("total3.csv", "a", newline='') as f:
        print(data, file=f)
            
start = time()

gz_files = glob.glob("*.gz")
pool = Pool()

print("Process started.")
pool.map(decomp, gz_files)

pool.close()
pool.join()

print('decompress is finished')
print('並列処理', (time()-start), "秒") #並列処理  秒 21GB
# Out:
# Process started.

# %%
"""
#辞書を指定したチャンクサイズに分割
def dict_chunks(data, size):
    it = iter(data)
    for i in range(0, len(data), size):
        yield{k:data[k] for k in islice(it, size)}
        
        
#現在のディレクトリ以下の全てのファイル名をキー、絶対パスを値とした辞書の作成
def mkdic(cwd_path):
    for curdir, subdir, subfile in os.walk(path, topdown=False):
        files_name = [i for i in subfile]
        files_path = [os.path.join(curdir, file) for file in subfile]
        gz_dict = dict(zip(files_name, files_path))
        return gz_dict
        

#以下参考コード(散乱したファイルの移動・集約）←上の処理に組み込んで省略予定
def copy_files(path):
    os.makedirs("copy", exist_ok=True)
    for curdir, subdir, subfile in os.walk(path, topdown=False):
        for file in subfile:
            file_path = os.path.join(curdir, file)
            try:
                shutil.copy(file_path, "copy")
            except Exception as err:
                print("発生したエラーの種類: {}".format(err))
                pass


start = time()
os.chdir("C:/users/genta212/practice")
current_path = os.getcwd()

copy_files(current_path)
print("file copy is finished")
print('逐次処理', (time()-start), "秒") #逐次処理 73.7738618850708 秒
"""
